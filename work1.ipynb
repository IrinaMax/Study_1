# %%
import requests
from urllib.request import urlopen
import urllib
import json
import nltk
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
# Out:
# /Users/irinamahmudjanova/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/feature_extraction/image.py:167: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int):
# /Users/irinamahmudjanova/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:35: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps,
# /Users/irinamahmudjanova/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:597: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /Users/irinamahmudjanova/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:836: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /Users/irinamahmudjanova/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /Users/irinamahmudjanova/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1095: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /Users/irinamahmudjanova/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1340: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /Users/irinamahmudjanova/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1476: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# /Users/irinamahmudjanova/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:152: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   precompute=False, eps=np.finfo(np.float).eps,
# /Users/irinamahmudjanova/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:320: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, random_state=None,
# /Users/irinamahmudjanova/anaconda3/envs/py3/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:580: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=4 * np.finfo(np.float).eps, n_jobs=None,

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
url = 'https://raw.githubusercontent.com/tosdr/tosdr.org/master/api/1/service/apple.json'

# %%
JSONContent = requests.get(url).json()
content = json.dumps(JSONContent, indent = 4, sort_keys=True)
print(content)
# Out:
# {
#     "alexa": 61,
#     "class": "D",
#     "links": {
#         "Apple Support Communities Use Agreement": {
#             "name": "Apple Support Communities Use Agreement",
#             "url": "https://discussions.apple.com/docs/DOC-5952"
#         },
#         "Apple Transparency Report": {
#             "name": "Apple Transparency Report",
#             "url": "https://www.apple.com/legal/transparency/"
#         },
#         "Application-Based Services Terms of Use": {
#             "name": "Application-Based Services Terms of Use",
#             "url": "http://www.apple.com/internetservices/terms/membership_terms.html"
#         },
#         "California Privacy Disclosure": {
#             "name": "California Privacy Disclosure",
#             "url": "https://www.apple.com/legal/privacy/california-dnt/"
#         },
#         "Game Center Terms and Conditions": {
#             "name": "Game Center Terms and Conditions",
#             "url": "https://www.apple.com/legal/internet-services/itunes/gamecenter/us/terms.html"
#         },
#         "Privacy Management Guide": {
#             "name": "Privacy Management Guide",
#             "url": "https://www.apple.com/privacy/manage-your-privacy/"
#         },
#         "Privacy Policy": {
#             "name": "Privacy Policy",
#             "url": "https://www.apple.com/legal/privacy/en-ww/"
#         },
#         "Website Terms of Service": {
#             "name": "Website Terms of Service",
#             "url": "http://www.apple.com/legal/internet-services/terms/site.html"
#         },
#         "iChat Account Terms of Service": {
#             "name": "iChat Account Terms of Service",
#             "url": "https://www.apple.com/legal/internet-services/terms/ichataccount.html"
#         },
#         "iCloud Terms of Service": {
#             "name": "iCloud Terms of Service",
#             "url": "https://www.apple.com/legal/internet-services/icloud/en/terms.html"
#         },
#         "iTunes Terms of Service": {
#             "name": "iTunes Terms of Service",
#             "url": "https://www.apple.com/legal/internet-services/itunes/us/terms.html"
#         }
#     },
#     "points": [
#         "10056",
#         "10287",
#         "11297",
#         "11298",
#         "11299",
#         "11300",
#         "11301",
#         "11717",
#         "1494",
#         "1595",
#         "1799",
#         "1819",
#         "2058",
#         "2210",
#         "5536",
#         "5540",
#         "5542",
#         "5543",
#         "5544",
#         "5545"
#     ],
#     "pointsData": {
#         "10056": {
#             "id": "10056",
#             "needModeration": false,
#             "quoteDoc": "iTunes Terms of Service",
#             "quoteEnd": 47340,
#             "quoteStart": 47132,
#             "quoteText": "You agree to comply with all local, state, federal, and national laws, statutes, ordinances, and regulations that apply to your use of the Services.\nYour use of the Services may also be subject to other laws.",
#             "services": [
#                 "apple"
#             ],
#             "title": "Users agree to comply with the law of the service's country",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "Users agree to comply with the law of the service's country",
#                 "point": "neutral",
#                 "score": 0,
#                 "tldr": "Generated through the annotate view"
#             }
#         },
#         "10287": {
#             "id": "10287",
#             "quoteDoc": "Privacy Policy",
#             "quoteEnd": 27630,
#             "quoteStart": 27453,
#             "quoteText": "Apple may update its Privacy Policy from time to time.\nWhen we change the policy in a material way, a notice will be posted on our website along with the updated Privacy Policy.",
#             "services": [
#                 "apple"
#             ],
#             "title": "The service may change its terms at any time, but the user will receive notification of the changes.",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "The service may change its terms at any time, but the user will receive notification of the changes.",
#                 "point": "neutral",
#                 "score": 0,
#                 "tldr": "Generated through the annotate view"
#             }
#         },
#         "11297": {
#             "id": "11297",
#             "quoteDoc": "Privacy Policy",
#             "quoteEnd": 9417,
#             "quoteStart": 9245,
#             "quoteText": "Apple\u2019s websites, online services, interactive applications, email messages, and advertisements may use \"cookies\" and other technologies such as pixel tags and web beacons.",
#             "services": [
#                 "apple"
#             ],
#             "title": "The service may use tracking pixels, web beacons, browser fingerprinting, and/or device fingerprinting on users.",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "The service may use tracking pixels, web beacons, browser fingerprinting, and/or device fingerprinting on users.",
#                 "point": "bad",
#                 "privacyRelated": true,
#                 "score": 50,
#                 "tldr": "Generated through the annotate view"
#             }
#         },
#         "11298": {
#             "id": "11298",
#             "quoteDoc": "Privacy Policy",
#             "quoteEnd": 1446,
#             "quoteStart": 1326,
#             "quoteText": "They may also combine it with other information to provide and improve our products, services, content, and advertising.",
#             "services": [
#                 "apple"
#             ],
#             "title": "This service may use your personal information for marketing purposes",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "This service may use your personal information for marketing purposes",
#                 "point": "bad",
#                 "privacyRelated": true,
#                 "score": 50,
#                 "tldr": "Generated through the annotate view"
#             }
#         },
#         "11299": {
#             "id": "11299",
#             "needModeration": false,
#             "quoteDoc": "Privacy Policy",
#             "quoteEnd": 24126,
#             "quoteStart": 23994,
#             "quoteText": "<p>All the information you provide may be transferred or accessed by entities around the world as described in this Privacy Policy.\n",
#             "services": [
#                 "apple"
#             ],
#             "title": "Your data may be processed and stored anywhere in the world",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "Your data may be processed and stored anywhere in the world",
#                 "point": "bad",
#                 "score": 25,
#                 "tldr": "Generated through the annotate view"
#             }
#         },
#         "11300": {
#             "id": "11300",
#             "quoteDoc": "Privacy Policy",
#             "quoteEnd": 12219,
#             "quoteStart": 12112,
#             "quoteText": "Please note that certain features of the Apple website will not be available once cookies are disabled.</p>",
#             "services": [
#                 "apple"
#             ],
#             "title": "Blocking first party cookies may limit your ability to use the service",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "Blocking first party cookies may limit your ability to use the service",
#                 "point": "neutral",
#                 "score": 50,
#                 "tldr": "Generated through the annotate view"
#             }
#         },
#         "11301": {
#             "id": "11301",
#             "quoteDoc": "iCloud Terms of Service",
#             "quoteEnd": 31146,
#             "quoteStart": 30800,
#             "quoteText": "However, Apple reserves the right at all times to determine whether Content is appropriate and in compliance with this Agreement, and may screen, move, refuse, modify and/or remove Content at any time, without prior notice and in its sole discretion, if such Content is found to be in violation of this Agreement or is otherwise objectionable.</p",
#             "services": [
#                 "apple"
#             ],
#             "title": "The service can delete specific content without reason and may do it without prior notice",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "The service can delete specific content without reason and may do it without prior notice",
#                 "point": "blocker",
#                 "score": 50,
#                 "tldr": "Generated through the annotate view"
#             }
#         },
#         "11717": {
#             "id": "11717",
#             "quoteDoc": "Privacy Policy",
#             "quoteEnd": 1325,
#             "quoteStart": 1077,
#             "quoteText": "You may be asked to provide your personal information anytime you are in contact with Apple or an Apple affiliated company.\nApple and its affiliates may share this personal information with each other and use it consistent with this Privacy Policy.",
#             "services": [
#                 "apple"
#             ],
#             "title": "This service can share your personal information to third parties ",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "This service can share your personal information to third parties ",
#                 "point": "bad",
#                 "privacyRelated": true,
#                 "score": 55,
#                 "tldr": "Generated through the annotate view"
#             }
#         },
#         "1494": {
#             "approved": false,
#             "id": "1494",
#             "needModeration": false,
#             "quoteDoc": "Website Terms of Service",
#             "quoteEnd": 875,
#             "quoteStart": 552,
#             "quoteText": "Apple reserves the right, at its sole discretion, to change, modify, add or remove portions of these Terms of Use, at any time.\nIt is your responsibility to check these Terms of Use periodically for changes.\nYour continued use of the Site following the posting of changes will mean that you accept and agree to the changes.",
#             "services": [
#                 "apple"
#             ],
#             "slug": "AAp5pMBtvk2Pkitvo",
#             "submittedBy": "L7MQPBDAkwgMZrR3P",
#             "title": " Terms may be changed any time at their discretion, without notice to the user ",
#             "topics": [
#                 "changes-notice"
#             ],
#             "tosdr": {
#                 "binding": true,
#                 "case": " Terms may be changed any time at their discretion, without notice to the user ",
#                 "point": "bad",
#                 "score": 70,
#                 "sources": [
#                     "http://www.apple.com/legal/internet-services/terms/site.html"
#                 ],
#                 "tldr": "Apple may change their Terms of Use at any time and it is your responsibility to keep up to date on these changes. By using the site you accept these terms."
#             }
#         },
#         "1595": {
#             "discussion": "https://groups.google.com/forum#!topic/tosdr/NDJ44InR1RE",
#             "id": "1595",
#             "needModeration": false,
#             "quoteDoc": "Website Terms of Service",
#             "quoteEnd": 12721,
#             "quoteStart": 12359,
#             "quoteText": "You agree to indemnify and hold Apple, its officers, directors, shareholders, predecessors, successors in interest, employees, agents, subsidiaries and affiliates, harmless from any demands, loss, liability, claims or expenses (including attorneys\u2019 fees), made against Apple by any third party due to or arising out of or in connection with your use of the Site.",
#             "services": [
#                 "apple"
#             ],
#             "slug": "NDJ44InR1RE",
#             "title": "You are solely responsible for claims made against the service and agree to indemnify and hold harmless the service.",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "You are solely responsible for claims made against the service and agree to indemnify and hold harmless the service.",
#                 "point": "bad",
#                 "score": 40,
#                 "tldr": "Apple.com indemnity"
#             }
#         },
#         "1799": {
#             "discussion": "https://groups.google.com/d/topic/tosdr/hDFO3k-z7fc/discussion",
#             "id": "1799",
#             "needModeration": false,
#             "quoteDoc": "Website Terms of Service",
#             "quoteEnd": 16306,
#             "quoteStart": 16133,
#             "quoteText": "You agree to the personal jurisdiction by and venue in the state and federal courts in Santa Clara County, California, and waive any objection to such jurisdiction or venue.",
#             "services": [
#                 "apple"
#             ],
#             "set": "set+service+and+topic",
#             "slug": "hDFO3k-z7fc",
#             "title": "The court of law governing the terms is in Santa Clara County, California",
#             "topics": [
#                 "jurisdiction-law"
#             ],
#             "tosdr": {
#                 "binding": true,
#                 "case": "The court of law governing the terms is in location X",
#                 "point": "neutral",
#                 "score": 0,
#                 "tldr": "Apple.com juristiction"
#             }
#         },
#         "1819": {
#             "discussion": "https://groups.google.com/forum#!topic/tosdr/CPHMJo29Vy8",
#             "id": "1819",
#             "needModeration": false,
#             "quoteDoc": "Website Terms of Service",
#             "quoteEnd": 11357,
#             "quoteStart": 10884,
#             "quoteText": "Apple reserves the right to do any of the following, at any time, without notice: (1) to modify, suspend or terminate operation of or access to the Site, or any portion of the Site, for any reason.\n(2) to modify or change the Site, or any portion of the Site, and any applicable policies or terms.\nand (3) to interrupt the operation of the Site, or any portion of the Site, as necessary to perform routine or non-routine maintenance, error correction, or other changes.</p>",
#             "services": [
#                 "apple"
#             ],
#             "slug": "CPHMJo29Vy8",
#             "title": "Apple.com can suspend the Site whenever they want, for any reason",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "They may stop providing the service at any time",
#                 "point": "bad",
#                 "score": 40,
#                 "tldr": "Apple.com can suspend the Site whenever they want, for any reason"
#             }
#         },
#         "2058": {
#             "discussion": "https://groups.google.com/forum#!topic/tosdr/fFPxjq8Yc-g",
#             "id": "2058",
#             "needModeration": false,
#             "quoteDoc": "Website Terms of Service",
#             "quoteEnd": 14531,
#             "quoteStart": 14236,
#             "quoteText": "You agree that Apple may, in its sole discretion and without prior notice, terminate your access to the Site and/or block your future access to the Site if we determine that you have violated these Terms of Use or other agreements or guidelines which may be associated with your use of the Site.",
#             "services": [
#                 "apple"
#             ],
#             "slug": "fFPxjq8Yc-g",
#             "title": "The service can suspend your account for several reasons",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "The service can suspend your account for several reasons",
#                 "point": "neutral",
#                 "score": 15,
#                 "tldr": "Apple.com can delete your account without notice"
#             }
#         },
#         "2210": {
#             "discussion": "https://groups.google.com/d/topic/tosdr/LfIH_KHkWgc/discussion",
#             "id": "2210",
#             "needModeration": false,
#             "quoteDoc": "Privacy Policy",
#             "quoteEnd": 21646,
#             "quoteStart": 21415,
#             "quoteText": "If we learn that we have collected the personal information of a child under 13, or equivalent minimum age depending on jurisdiction, outside the above circumstances we will take steps to delete the information as soon as possible.",
#             "services": [
#                 "apple"
#             ],
#             "set": "set+service+and+topic",
#             "slug": "LfIH_KHkWgc",
#             "title": "Apple.com has an age restriction of 13 years",
#             "topics": [
#                 "governance"
#             ],
#             "tosdr": {
#                 "binding": true,
#                 "case": "This service is only available to users over a certain age",
#                 "point": "neutral",
#                 "score": 15,
#                 "tldr": "Apple.com has an age restriction of 13 years"
#             }
#         },
#         "5536": {
#             "id": "5536",
#             "needModeration": false,
#             "quoteDoc": "iCloud Terms of Service",
#             "quoteEnd": 5473,
#             "quoteStart": 5076,
#             "quoteText": "Apple reserves the right at any time to modify this Agreement and to impose new or additional terms or conditions on your use of the Service, provided that Apple will give you 30 days\u2019 advance notice of any material adverse change to the Service or applicable terms of service, unless it would not be reasonable to do so due to circumstances arising from legal, regulatory, or governmental action.",
#             "services": [
#                 "apple"
#             ],
#             "title": "When the service wants to change its terms, users are notified a month or more in advance",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "When the service wants to make a material change to its terms, users are notified at least 30 days in advance",
#                 "point": "good",
#                 "score": 40,
#                 "tldr": "Generated through the annotate view"
#             }
#         },
#         "5540": {
#             "id": "5540",
#             "needModeration": false,
#             "quoteDoc": "iCloud Terms of Service",
#             "quoteEnd": 42392,
#             "quoteStart": 42321,
#             "quoteText": "You may delete your Apple ID and/or stop using the Service at any time.",
#             "services": [
#                 "apple"
#             ],
#             "title": "You have the right to leave this service at any time",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "You have the right to leave this service at any time",
#                 "point": "good",
#                 "score": 15,
#                 "tldr": "Generated through the annotate view"
#             }
#         },
#         "5542": {
#             "id": "5542",
#             "needModeration": false,
#             "quoteDoc": "iCloud Terms of Service",
#             "quoteEnd": 44188,
#             "quoteStart": 44045,
#             "quoteText": "Apple will be permitted to terminate only after giving you 30 days\u2019 notice and only if you have not cured the breach within such 30-day period.",
#             "services": [
#                 "apple"
#             ],
#             "title": "The service gives 30 days of notice before closing your account",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "The service gives 30 days of notice before closing your account",
#                 "point": "good",
#                 "score": 15,
#                 "tldr": "Generated through the annotate view"
#             }
#         },
#         "5543": {
#             "id": "5543",
#             "needModeration": false,
#             "quoteDoc": "Privacy Policy",
#             "quoteEnd": 18316,
#             "quoteStart": 18144,
#             "quoteText": "For other personal information we hold, we will provide you with access (including a copy) for any purpose including to request that we correct the data if it is inaccurate",
#             "services": [
#                 "apple"
#             ],
#             "title": "You can request access and deletion of personal data",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "You can request access and deletion of personal data",
#                 "point": "good",
#                 "privacyRelated": true,
#                 "score": 50,
#                 "tldr": "Generated through the annotate view"
#             }
#         },
#         "5544": {
#             "id": "5544",
#             "needModeration": false,
#             "quoteDoc": "Privacy Policy",
#             "quoteEnd": 18417,
#             "quoteStart": 18317,
#             "quoteText": "or delete the data if Apple is not required to retain it by law or for legitimate business purposes.",
#             "services": [
#                 "apple"
#             ],
#             "title": "You can request access and deletion of personal data",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "You can request access and deletion of personal data",
#                 "point": "good",
#                 "privacyRelated": true,
#                 "score": 50,
#                 "tldr": "Generated through the annotate view"
#             }
#         },
#         "5545": {
#             "id": "5545",
#             "needModeration": false,
#             "quoteDoc": "Privacy Policy",
#             "quoteEnd": 17951,
#             "quoteStart": 17512,
#             "quoteText": "We will retain your personal information for the period necessary to fulfill the purposes outlined in this Privacy Policy and our service specific privacy summaries.\nWhen assessing these periods we carefully examine our need to collect personal information at all and if we establish a relevant need we only retain it for the shortest possible period to realize the purpose of collection unless a longer retention period is required by law",
#             "services": [
#                 "apple"
#             ],
#             "title": "The service's data retention period is kept to the minimum necessary for fulfilling its purposes",
#             "topics": [],
#             "tosdr": {
#                 "binding": true,
#                 "case": "The service's data retention period is kept to the minimum necessary for fulfilling its purposes",
#                 "point": "good",
#                 "privacyRelated": true,
#                 "score": 50,
#                 "tldr": "Generated through the annotate view"
#             }
#         }
#     },
#     "urls": [
#         "apple.com"
#     ]
# }

# %%
jdata = json.loads(content)

# %%
#df = pd.json_normalize(jdata )
df = pd.DataFrame.from_dict(pd.json_normalize(jdata))

# %%
print(df)
# Out:
#    alexa class                                             points  \
# 0     61     D  [10056, 10287, 11297, 11298, 11299, 11300, 113...
#
#           urls links.Apple Support Communities Use Agreement.name  \
# 0  [apple.com]            Apple Support Communities Use Agreement
#
#   links.Apple Support Communities Use Agreement.url  \
# 0       https://discussions.apple.com/docs/DOC-5952
#
#   links.Apple Transparency Report.name  \
# 0            Apple Transparency Report
#
#          links.Apple Transparency Report.url  \
# 0  https://www.apple.com/legal/transparency/
#
#   links.Application-Based Services Terms of Use.name  \
# 0            Application-Based Services Terms of Use
#
#    links.Application-Based Services Terms of Use.url  ...  \
# 0  http://www.apple.com/internetservices/terms/me...  ...
#
#                            pointsData.5545.quoteText pointsData.5545.services  \
# 0  We will retain your personal information for t...                  [apple]
#
#                                pointsData.5545.title pointsData.5545.topics  \
# 0  The service's data retention period is kept to...                     []
#
#   pointsData.5545.tosdr.binding  \
# 0                          True
#
#                           pointsData.5545.tosdr.case  \
# 0  The service's data retention period is kept to...
#
#   pointsData.5545.tosdr.point pointsData.5545.tosdr.privacyRelated  \
# 0                        good                                 True
#
#   pointsData.5545.tosdr.score           pointsData.5545.tosdr.tldr
# 0                          50  Generated through the annotate view
#
# [1 rows x 322 columns]

# %%
df = pd.DataFrame.from_dict(pd.json_normalize(jdata))
df
# Out:
#    alexa class                                             points  \
# 0     61     D  [10056, 10287, 11297, 11298, 11299, 11300, 113...
#
#           urls links.Apple Support Communities Use Agreement.name  \
# 0  [apple.com]            Apple Support Communities Use Agreement
#
#   links.Apple Support Communities Use Agreement.url  \
# 0       https://discussions.apple.com/docs/DOC-5952
#
#   links.Apple Transparency Report.name  \
# 0            Apple Transparency Report
#
#          links.Apple Transparency Report.url  \
# 0  https://www.apple.com/legal/transparency/
#
#   links.Application-Based Services Terms of Use.name  \
# 0            Application-Based Services Terms of Use
#
#    links.Application-Based Services Terms of Use.url  ...  \
# 0  http://www.apple.com/internetservices/terms/me...  ...
#
#                            pointsData.5545.quoteText pointsData.5545.services  \
# 0  We will retain your personal information for t...                  [apple]
#
#                                pointsData.5545.title pointsData.5545.topics  \
# 0  The service's data retention period is kept to...                     []
#
#   pointsData.5545.tosdr.binding  \
# 0                          True
#
#                           pointsData.5545.tosdr.case  \
# 0  The service's data retention period is kept to...
#
#   pointsData.5545.tosdr.point pointsData.5545.tosdr.privacyRelated  \
# 0                        good                                 True
#
#   pointsData.5545.tosdr.score           pointsData.5545.tosdr.tldr
# 0                          50  Generated through the annotate view
#
# [1 rows x 322 columns]

# %%
# will try to transpose
print(np.transpose(df))
# Out:
#                                                                                                     0
# alexa                                                                                              61
# class                                                                                               D
# points                                              [10056, 10287, 11297, 11298, 11299, 11300, 113...
# urls                                                                                      [apple.com]
# links.Apple Support Communities Use Agreement.name            Apple Support Communities Use Agreement
# ...                                                                                               ...
# pointsData.5545.tosdr.case                          The service's data retention period is kept to...
# pointsData.5545.tosdr.point                                                                      good
# pointsData.5545.tosdr.privacyRelated                                                             True
# pointsData.5545.tosdr.score                                                                        50
# pointsData.5545.tosdr.tldr                                        Generated through the annotate view
#
# [322 rows x 1 columns]

# %%
df = pd.DataFrame.from_dict(pd.json_normalize(jdata), orient = 'columns')

# %%
df
# Out:
#    alexa class                                             points  \
# 0     61     D  [10056, 10287, 11297, 11298, 11299, 11300, 113...
#
#           urls links.Apple Support Communities Use Agreement.name  \
# 0  [apple.com]            Apple Support Communities Use Agreement
#
#   links.Apple Support Communities Use Agreement.url  \
# 0       https://discussions.apple.com/docs/DOC-5952
#
#   links.Apple Transparency Report.name  \
# 0            Apple Transparency Report
#
#          links.Apple Transparency Report.url  \
# 0  https://www.apple.com/legal/transparency/
#
#   links.Application-Based Services Terms of Use.name  \
# 0            Application-Based Services Terms of Use
#
#    links.Application-Based Services Terms of Use.url  ...  \
# 0  http://www.apple.com/internetservices/terms/me...  ...
#
#                            pointsData.5545.quoteText pointsData.5545.services  \
# 0  We will retain your personal information for t...                  [apple]
#
#                                pointsData.5545.title pointsData.5545.topics  \
# 0  The service's data retention period is kept to...                     []
#
#   pointsData.5545.tosdr.binding  \
# 0                          True
#
#                           pointsData.5545.tosdr.case  \
# 0  The service's data retention period is kept to...
#
#   pointsData.5545.tosdr.point pointsData.5545.tosdr.privacyRelated  \
# 0                        good                                 True
#
#   pointsData.5545.tosdr.score           pointsData.5545.tosdr.tldr
# 0                          50  Generated through the annotate view
#
# [1 rows x 322 columns]

# %%
# will try to expract only point with text 
df.loc[:, df.columns.str.startswith('pointsData')]
# Out:
#   pointsData.10056.id  pointsData.10056.needModeration  \
# 0               10056                            False
#
#   pointsData.10056.quoteDoc  pointsData.10056.quoteEnd  \
# 0   iTunes Terms of Service                      47340
#
#    pointsData.10056.quoteStart  \
# 0                        47132
#
#                           pointsData.10056.quoteText  \
# 0  You agree to comply with all local, state, fed...
#
#   pointsData.10056.services  \
# 0                   [apple]
#
#                               pointsData.10056.title pointsData.10056.topics  \
# 0  Users agree to comply with the law of the serv...                      []
#
#    pointsData.10056.tosdr.binding  ...  \
# 0                            True  ...
#
#                            pointsData.5545.quoteText pointsData.5545.services  \
# 0  We will retain your personal information for t...                  [apple]
#
#                                pointsData.5545.title pointsData.5545.topics  \
# 0  The service's data retention period is kept to...                     []
#
#   pointsData.5545.tosdr.binding  \
# 0                          True
#
#                           pointsData.5545.tosdr.case  \
# 0  The service's data retention period is kept to...
#
#    pointsData.5545.tosdr.point  pointsData.5545.tosdr.privacyRelated  \
# 0                         good                                  True
#
#   pointsData.5545.tosdr.score           pointsData.5545.tosdr.tldr
# 0                          50  Generated through the annotate view
#
# [1 rows x 296 columns]

# %%
# filter only title
df.filter(regex= 'title')
# Out:
#                               pointsData.10056.title  \
# 0  Users agree to comply with the law of the serv...
#
#                               pointsData.10287.title  \
# 0  The service may change its terms at any time, ...
#
#                               pointsData.11297.title  \
# 0  The service may use tracking pixels, web beaco...
#
#                               pointsData.11298.title  \
# 0  This service may use your personal information...
#
#                               pointsData.11299.title  \
# 0  Your data may be processed and stored anywhere...
#
#                               pointsData.11300.title  \
# 0  Blocking first party cookies may limit your ab...
#
#                               pointsData.11301.title  \
# 0  The service can delete specific content withou...
#
#                               pointsData.11717.title  \
# 0  This service can share your personal informati...
#
#                                pointsData.1494.title  \
# 0   Terms may be changed any time at their discre...
#
#                                pointsData.1595.title  \
# 0  You are solely responsible for claims made aga...
#
#                                pointsData.1799.title  \
# 0  The court of law governing the terms is in San...
#
#                                pointsData.1819.title  \
# 0  Apple.com can suspend the Site whenever they w...
#
#                                pointsData.2058.title  \
# 0  The service can suspend your account for sever...
#
#                           pointsData.2210.title  \
# 0  Apple.com has an age restriction of 13 years
#
#                                pointsData.5536.title  \
# 0  When the service wants to change its terms, us...
#
#                                pointsData.5540.title  \
# 0  You have the right to leave this service at an...
#
#                                pointsData.5542.title  \
# 0  The service gives 30 days of notice before clo...
#
#                                pointsData.5543.title  \
# 0  You can request access and deletion of persona...
#
#                                pointsData.5544.title  \
# 0  You can request access and deletion of persona...
#
#                                pointsData.5545.title
# 0  The service's data retention period is kept to...

# %%
df2 = df.filter(regex= 'title') 
df2.shape
# Out:
# (1, 20)

# %%
print(np.transpose(df2))
df2 = np.transpose(df2)
# Out:
#                                                                         0
# pointsData.10056.title  Users agree to comply with the law of the serv...
# pointsData.10287.title  The service may change its terms at any time, ...
# pointsData.11297.title  The service may use tracking pixels, web beaco...
# pointsData.11298.title  This service may use your personal information...
# pointsData.11299.title  Your data may be processed and stored anywhere...
# pointsData.11300.title  Blocking first party cookies may limit your ab...
# pointsData.11301.title  The service can delete specific content withou...
# pointsData.11717.title  This service can share your personal informati...
# pointsData.1494.title    Terms may be changed any time at their discre...
# pointsData.1595.title   You are solely responsible for claims made aga...
# pointsData.1799.title   The court of law governing the terms is in San...
# pointsData.1819.title   Apple.com can suspend the Site whenever they w...
# pointsData.2058.title   The service can suspend your account for sever...
# pointsData.2210.title        Apple.com has an age restriction of 13 years
# pointsData.5536.title   When the service wants to change its terms, us...
# pointsData.5540.title   You have the right to leave this service at an...
# pointsData.5542.title   The service gives 30 days of notice before clo...
# pointsData.5543.title   You can request access and deletion of persona...
# pointsData.5544.title   You can request access and deletion of persona...
# pointsData.5545.title   The service's data retention period is kept to...

# %%
df2
# Out:
#                                                                         0
# pointsData.10056.title  Users agree to comply with the law of the serv...
# pointsData.10287.title  The service may change its terms at any time, ...
# pointsData.11297.title  The service may use tracking pixels, web beaco...
# pointsData.11298.title  This service may use your personal information...
# pointsData.11299.title  Your data may be processed and stored anywhere...
# pointsData.11300.title  Blocking first party cookies may limit your ab...
# pointsData.11301.title  The service can delete specific content withou...
# pointsData.11717.title  This service can share your personal informati...
# pointsData.1494.title    Terms may be changed any time at their discre...
# pointsData.1595.title   You are solely responsible for claims made aga...
# pointsData.1799.title   The court of law governing the terms is in San...
# pointsData.1819.title   Apple.com can suspend the Site whenever they w...
# pointsData.2058.title   The service can suspend your account for sever...
# pointsData.2210.title        Apple.com has an age restriction of 13 years
# pointsData.5536.title   When the service wants to change its terms, us...
# pointsData.5540.title   You have the right to leave this service at an...
# pointsData.5542.title   The service gives 30 days of notice before clo...
# pointsData.5543.title   You can request access and deletion of persona...
# pointsData.5544.title   You can request access and deletion of persona...
# pointsData.5545.title   The service's data retention period is kept to...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk import tokenize
sid = SentimentIntensityAnalyzer()

# %%
messages = df2[0]
for m in messages:
    vs = sid.polarity_scores(m)
    print("{:<70} {}".format(m, str(vs)))
# Out:
# Users agree to comply with the law of the service's country            {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.3612}
# The service may change its terms at any time, but the user will receive notification of the changes. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# The service may use tracking pixels, web beacons, browser fingerprinting, and/or device fingerprinting on users. {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# This service may use your personal information for marketing purposes  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Your data may be processed and stored anywhere in the world            {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Blocking first party cookies may limit your ability to use the service {'neg': 0.157, 'neu': 0.542, 'pos': 0.301, 'compound': 0.34}
# The service can delete specific content without reason and may do it without prior notice {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# This service can share your personal information to third parties      {'neg': 0.0, 'neu': 0.62, 'pos': 0.38, 'compound': 0.5994}
#  Terms may be changed any time at their discretion, without notice to the user  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# You are solely responsible for claims made against the service and agree to indemnify and hold harmless the service. {'neg': 0.0, 'neu': 0.702, 'pos': 0.298, 'compound': 0.7003}
# The court of law governing the terms is in Santa Clara County, California {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Apple.com can suspend the Site whenever they want, for any reason      {'neg': 0.183, 'neu': 0.714, 'pos': 0.103, 'compound': -0.25}
# The service can suspend your account for several reasons               {'neg': 0.223, 'neu': 0.777, 'pos': 0.0, 'compound': -0.3182}
# Apple.com has an age restriction of 13 years                           {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'compound': -0.2732}
# When the service wants to change its terms, users are notified a month or more in advance {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# You have the right to leave this service at any time                   {'neg': 0.107, 'neu': 0.893, 'pos': 0.0, 'compound': -0.0516}
# The service gives 30 days of notice before closing your account        {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# You can request access and deletion of personal data                   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# You can request access and deletion of personal data                   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# The service's data retention period is kept to the minimum necessary for fulfilling its purposes {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
analyzer = SentimentIntensityAnalyzer()
data_all = df2[0]

# %%
messages = []
vs_compound = []
vs_pos = []
vs_neu = []
vs_neg = []

for i in range(0, len(data_all)):
    messages.append(data_all[i])
    vs_compound.append(analyzer.polarity_scores(data_all[i])['compound'])
    vs_pos.append(analyzer.polarity_scores(data_all[i])['pos'])
    vs_neu.append(analyzer.polarity_scores(data_all[i])['neu'])
    vs_neg.append(analyzer.polarity_scores(data_all[i])['neg'])

# %%
dfsa = pd.DataFrame({'Messages': messages,
                        'Compound': vs_compound,
                        'Positive': vs_pos,
                        'Neutral': vs_neu,
                        'Negative': vs_neg})
dfsa = dfsa[['Messages', 'Compound', 'Positive', 'Neutral', 'Negative']]

# %%
dfsa
# Out:
#                                              Messages  Compound  Positive  \
# 0   Users agree to comply with the law of the serv...    0.3612     0.200
# 1   The service may change its terms at any time, ...    0.0000     0.000
# 2   The service may use tracking pixels, web beaco...    0.0000     0.000
# 3   This service may use your personal information...    0.0000     0.000
# 4   Your data may be processed and stored anywhere...    0.0000     0.000
# 5   Blocking first party cookies may limit your ab...    0.3400     0.301
# 6   The service can delete specific content withou...    0.0000     0.000
# 7   This service can share your personal informati...    0.5994     0.380
# 8    Terms may be changed any time at their discre...    0.0000     0.000
# 9   You are solely responsible for claims made aga...    0.7003     0.298
# 10  The court of law governing the terms is in San...    0.0000     0.000
# 11  Apple.com can suspend the Site whenever they w...   -0.2500     0.103
# 12  The service can suspend your account for sever...   -0.3182     0.000
# 13       Apple.com has an age restriction of 13 years   -0.2732     0.000
# 14  When the service wants to change its terms, us...    0.0000     0.000
# 15  You have the right to leave this service at an...   -0.0516     0.000
# 16  The service gives 30 days of notice before clo...    0.0000     0.000
# 17  You can request access and deletion of persona...    0.0000     0.000
# 18  You can request access and deletion of persona...    0.0000     0.000
# 19  The service's data retention period is kept to...    0.0000     0.000
#
#     Neutral  Negative
# 0     0.800     0.000
# 1     1.000     0.000
# 2     1.000     0.000
# 3     1.000     0.000
# 4     1.000     0.000
# 5     0.542     0.157
# 6     1.000     0.000
# 7     0.620     0.000
# 8     1.000     0.000
# 9     0.702     0.000
# 10    1.000     0.000
# 11    0.714     0.183
# 12    0.777     0.223
# 13    0.769     0.231
# 14    1.000     0.000
# 15    0.893     0.107
# 16    1.000     0.000
# 17    1.000     0.000
# 18    1.000     0.000
# 19    1.000     0.000
